# %% [markdown]
# # House sales in King County dataset from Kaggle
#
# https://www.kaggle.com/datasets/harlfoxem/housesalesprediction/data

# %% [markdown]
# ## Read csv file to get insights

# %%
import pandas as pd

# %%
house=pd.read_csv("kc_house_data.csv")

# %%
house.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21613 non-null  int64
#  1   date           21613 non-null  object
#  2   price          21613 non-null  float64
#  3   bedrooms       21613 non-null  int64
#  4   bathrooms      21613 non-null  float64
#  5   sqft_living    21613 non-null  int64
#  6   sqft_lot       21613 non-null  int64
#  7   floors         21613 non-null  float64
#  8   waterfront     21613 non-null  int64
#  9   view           21613 non-null  int64
#  10  condition      21613 non-null  int64
#  11  grade          21613 non-null  int64
#  12  sqft_above     21613 non-null  int64
#  13  sqft_basement  21613 non-null  int64
#  14  yr_built       21613 non-null  int64
#  15  yr_renovated   21613 non-null  int64
#  16  zipcode        21613 non-null  int64
# ...

# %%
house.shape
# Out:
# (21613, 21)

# %%
house.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %%
mask=house.isnull()
mask
# Out:
#           id   date  price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0      False  False  False     False      False        False     False
# 1      False  False  False     False      False        False     False
# 2      False  False  False     False      False        False     False
# 3      False  False  False     False      False        False     False
# 4      False  False  False     False      False        False     False
# ...      ...    ...    ...       ...        ...          ...       ...
# 21608  False  False  False     False      False        False     False
# 21609  False  False  False     False      False        False     False
# 21610  False  False  False     False      False        False     False
# 21611  False  False  False     False      False        False     False
# 21612  False  False  False     False      False        False     False
#
#        floors  waterfront   view  ...  grade  sqft_above  sqft_basement  \
# ...

# %%
house.dropna()
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000  221900.0         3       1.00
# 1      6414100192  20141209T000000  538000.0         3       2.25
# 2      5631500400  20150225T000000  180000.0         2       1.00
# 3      2487200875  20141209T000000  604000.0         4       3.00
# 4      1954400510  20150218T000000  510000.0         3       2.00
# ...           ...              ...       ...       ...        ...
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 0             1180      5650     1.0           0     0  ...      7
# ...

# %% [markdown]
# Shape is still 21613 rows x 21 columns => No null

# %%
house.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %% [markdown]
# ## Explain dataset
#
# Reference: https://rstudio-pubs-static.s3.amazonaws.com/155304_cc51f448116744069664b35e7762999f.html
#
# * id: unique id of home sold
# * date: date of the home sale
# * price: price of each home sold
# * bedrooms: number of bedrooms
# * bathrooms: number of bathrooms: .25: toilet only, .5: bathroom with toilet and no shower, .75: sink, toilet, and without tub or shower
# * sqft_living: square footage of the apartments interior living space
# * sqft_lot: square footage of the land space
# * floors: number of floors
# * waterfront: whether the apartment was overlooking the river or not (0: no, 1: yes)
# * view: 0 to 4 to indicate how good the view was
# * condition: 1 to 5 to show the condition of the apartment
# * grade: 1 to 13. 1-3: short of building construction and design, 7: average level of construction and design, 11-13: high quality level of construction and design.
# * sqft_above: square footage of the interior housing space that is above ground level
# * sqft_basement: square footage of the interior housing space that is below ground level
# * yr_built: year the house was initially built
# * yr_renovated: year of the house’s last renovation
# * zipcode: zipcode area the house is in
# * lat: lattitude
# * long: longitude
# * sqft_living15: square footage of interior housing living space for the nearest 15 neighbors
# * sqft_lot15: square footage of the land lots of the nearest 15 neighbors

# %%
house.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %%
#Rename some columns
df=house.rename(columns={"lat": "latitude", "long": "longtitude"})

# %%
df.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'latitude', 'longtitude', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %% [markdown]
# ## Handle categorical values

# %%
df['view'].value_counts()
# Out:
# 0    19489
# 2      963
# 3      510
# 1      332
# 4      319
# Name: view, dtype: int64

# %%
#0: No view
#1: Fair
#2: Average
#3: Good
#4: Excellent
df['view'].replace([0,1,2,3,4],['No view','Fair','Average','Good','Excellent'], inplace=True)

# %%
df.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront     view  ...  grade  sqft_above  \
# 0      5650     1.0           0  No view  ...      7        1180
# 1      7242     2.0           0  No view  ...      7        2170
# 2     10000     1.0           0  No view  ...      6         770
# 3      5000     1.0           0  No view  ...      7        1050
# 4      8080     1.0           0  No view  ...      8        1680
#
#    sqft_basement  yr_built  yr_renovated  zipcode  latitude  longtitude  \
# ...

# %%
df['condition'].value_counts()
# Out:
# 3    14031
# 4     5679
# 5     1701
# 2      172
# 1       30
# Name: condition, dtype: int64

# %%
#1: Poor - Worn out
#2: Fair - Badly worn
#3: Average
#4: Good
#5: Very good
df['condition'].replace([1,2,3,4,5],['Poor - Worn out','Fair - Badly worn','Average','Good','Very good'], inplace=True)

# %%
df['condition'].value_counts()
# Out:
# Average              14031
# Good                  5679
# Very good             1701
# Fair - Badly worn      172
# Poor - Worn out         30
# Name: condition, dtype: int64

# %%
df['grade'].value_counts()
# Out:
# 7     8981
# 8     6068
# 9     2615
# 6     2038
# 10    1134
# 11     399
# 5      242
# 12      90
# 4       29
# 13      13
# 3        3
# 1        1
# Name: grade, dtype: int64

# %%
newdf=df
#newdf['construction_design_level']=newdf['grade']

# %%
newdf.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront     view  ... grade  sqft_above  \
# 0      5650     1.0           0  No view  ...     7        1180
# 1      7242     2.0           0  No view  ...     7        2170
# 2     10000     1.0           0  No view  ...     6         770
# 3      5000     1.0           0  No view  ...     7        1050
# 4      8080     1.0           0  No view  ...     8        1680
#
#    sqft_basement  yr_built  yr_renovated  zipcode  latitude  longtitude  \
# ...

# %%
newdf['construction_design_level']=newdf['grade']

# %%
newdf['construction_design_level'].value_counts()
# Out:
# 7     8981
# 8     6068
# 9     2615
# 6     2038
# 10    1134
# 11     399
# 5      242
# 12      90
# 4       29
# 13      13
# 3        3
# 1        1
# Name: construction_design_level, dtype: int64

# %%
#1->3: low
#4->6: fair
#7: average
#8-10: good
#11-13: high quality
def categorizeGrade(grade):
    if grade>=1 & grade<=3: return "Low"
    elif grade>=4 & grade<=6: return "Fair"
    elif grade==7: return "Average"
    elif grade>=8 & grade<=10: return "Good"
    elif grade>=11 & grade<=13: return "High"

# %%
newdf['construction_design_level']=newdf['grade'].apply(lambda x: categorizeGrade(x))

# %%
newdf.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'latitude', 'longtitude', 'sqft_living15', 'sqft_lot15',
#        'construction_design_level'],
#       dtype='object')

# %%
newdf.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront     view  ... sqft_above  sqft_basement  \
# 0      5650     1.0           0  No view  ...       1180              0
# 1      7242     2.0           0  No view  ...       2170            400
# 2     10000     1.0           0  No view  ...        770              0
# 3      5000     1.0           0  No view  ...       1050            910
# 4      8080     1.0           0  No view  ...       1680              0
#
#    yr_built  yr_renovated  zipcode  latitude  longtitude  sqft_living15  \
# ...

# %%
import numpy as np

# %%
newdf['renovate_year_since_built']=pd.Series(np.where((newdf['yr_renovated'] > newdf['yr_built']) & (newdf['yr_renovated'] != 0),
                                      newdf['yr_renovated'] - df['yr_built'], 0), index=df.index)

# %%
newdf.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront     view  ... sqft_basement  yr_built  \
# 0      5650     1.0           0  No view  ...             0      1955
# 1      7242     2.0           0  No view  ...           400      1951
# 2     10000     1.0           0  No view  ...             0      1933
# 3      5000     1.0           0  No view  ...           910      1965
# 4      8080     1.0           0  No view  ...             0      1987
#
#    yr_renovated  zipcode  latitude  longtitude  sqft_living15  sqft_lot15  \
# ...

# %%
newdf['waterfront'].replace([0,1],['No', 'Yes'], inplace=True)

# %%
newdf.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors waterfront     view  ... sqft_basement  yr_built  \
# 0      5650     1.0         No  No view  ...             0      1955
# 1      7242     2.0         No  No view  ...           400      1951
# 2     10000     1.0         No  No view  ...             0      1933
# 3      5000     1.0         No  No view  ...           910      1965
# 4      8080     1.0         No  No view  ...             0      1987
#
#    yr_renovated  zipcode  latitude  longtitude  sqft_living15  sqft_lot15  \
# ...

# %%
newdf['price_per_sqft']=newdf['price']/newdf['sqft_lot']

# %%
newdf['price_per_sqft']
# Out:
# 0         39.274336
# 1         74.288870
# 2         18.000000
# 3        120.800000
# 4         63.118812
#             ...
# 21608    318.302387
# 21609     68.811285
# 21610    297.852593
# 21611    167.504188
# 21612    302.044610
# Name: price_per_sqft, Length: 21613, dtype: float64

# %%
newdf.to_excel('KCHouseFinal.xlsx', index=False)
